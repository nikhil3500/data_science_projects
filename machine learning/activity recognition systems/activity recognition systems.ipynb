# %% [markdown]
# # 1. Import the dataset in Jupyter Notebook using pandas library

# %%
import pandas as pd

# %%
data=pd.read_csv(r"SmartWatch Data (1) (2).csv")

# %%
data.head()
# Out:
#    X1  age  gender  height  weight      steps  hear_rate   calories  distance  \
# 0   1   20       1   168.0    65.4  10.771429  78.531302   0.344533  0.008327
# 1   2   20       1   168.0    65.4  11.475325  78.453390   3.287625  0.008896
# 2   3   20       1   168.0    65.4  12.179221  78.540825   9.484000  0.009466
# 3   4   20       1   168.0    65.4  12.883117  78.628260  10.154556  0.010035
# 4   5   20       1   168.0    65.4  13.587013  78.715695  10.825111  0.010605
#
#    entropy_heart  entropy_setps  resting_heart  corr_heart_steps  norm_heart  \
# 0       6.221612       6.116349           59.0          1.000000   19.531302
# 1       6.221612       6.116349           59.0          1.000000   19.453390
# 2       6.221612       6.116349           59.0          1.000000   19.540825
# 3       6.221612       6.116349           59.0          1.000000   19.628260
# 4       6.221612       6.116349           59.0          0.982816   19.715695
#
# ...

# %% [markdown]
# # 2. Find out whether Supervised or Unsupervised Machine Learning should be used?
# Answer. This is a Supervised Learning . Target variable is activity.

# %% [markdown]
# # 3. If Supervised, is this a problem statement of Regression or Classification?
# Answer. This is a Classification problem.Target variable activity have categories Lying,Walking,Running.

# %% [markdown]
# # 4. Check the quality of the data, it’s shape and data types

# %%
data.shape
# Out:
# (6264, 19)

# %%
data.dtypes
# Out:
# X1                        int64
# age                       int64
# gender                    int64
# height                  float64
# weight                  float64
# steps                   float64
# hear_rate               float64
# calories                float64
# distance                float64
# entropy_heart           float64
# entropy_setps           float64
# resting_heart           float64
# corr_heart_steps        float64
# norm_heart              float64
# intensity_karvonen      float64
# sd_norm_heart           float64
# steps_times_distance    float64
# device                   object
# activity                 object
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6264 entries, 0 to 6263
# Data columns (total 19 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   X1                    6264 non-null   int64
#  1   age                   6264 non-null   int64
#  2   gender                6264 non-null   int64
#  3   height                6264 non-null   float64
#  4   weight                6264 non-null   float64
#  5   steps                 6264 non-null   float64
#  6   hear_rate             6264 non-null   float64
#  7   calories              6264 non-null   float64
#  8   distance              6264 non-null   float64
#  9   entropy_heart         6264 non-null   float64
#  10  entropy_setps         6264 non-null   float64
#  11  resting_heart         6264 non-null   float64
#  12  corr_heart_steps      6264 non-null   float64
#  13  norm_heart            6264 non-null   float64
# ...

# %%
data.describe()
# Out:
#                 X1          age       gender       height       weight  \
# count  6264.000000  6264.000000  6264.000000  6264.000000  6264.000000
# mean   1771.144317    29.158525     0.476533   169.709052    69.614464
# std    1097.988748     8.908978     0.499489    10.324698    13.451878
# min       1.000000    18.000000     0.000000   143.000000    43.000000
# 25%     789.750000    23.000000     0.000000   160.000000    60.000000
# 50%    1720.000000    28.000000     0.000000   168.000000    68.000000
# 75%    2759.250000    33.000000     1.000000   180.000000    77.300000
# max    3670.000000    56.000000     1.000000   191.000000   115.000000
#
#              steps    hear_rate     calories     distance  entropy_heart  \
# count  6264.000000  6264.000000  6264.000000  6264.000000    6264.000000
# mean    109.562268    86.142331    19.471823    13.832555       6.030314
# std     222.797908    28.648385    27.309765    45.941437       0.765574
# ...

# %% [markdown]
# # 5. Check for null values, and apply appropriate techniques deal with it

# %%
data.isnull()
# Out:
#          X1    age  gender  height  weight  steps  hear_rate  calories  \
# 0     False  False   False   False   False  False      False     False
# 1     False  False   False   False   False  False      False     False
# 2     False  False   False   False   False  False      False     False
# 3     False  False   False   False   False  False      False     False
# 4     False  False   False   False   False  False      False     False
# ...     ...    ...     ...     ...     ...    ...        ...       ...
# 6259  False  False   False   False   False  False      False     False
# 6260  False  False   False   False   False  False      False     False
# 6261  False  False   False   False   False  False      False     False
# 6262  False  False   False   False   False  False      False     False
# 6263  False  False   False   False   False  False      False     False
#
#       distance  entropy_heart  entropy_setps  resting_heart  corr_heart_steps  \
# ...

# %%
data.isnull().sum()
# Out:
# X1                      0
# age                     0
# gender                  0
# height                  0
# weight                  0
# steps                   0
# hear_rate               0
# calories                0
# distance                0
# entropy_heart           0
# entropy_setps           0
# resting_heart           0
# corr_heart_steps        0
# norm_heart              0
# intensity_karvonen      0
# sd_norm_heart           0
# steps_times_distance    0
# device                  0
# activity                0
# dtype: int64

# %% [markdown]
# # 6. Find and remove outliers if any

# %%
import numpy as np

# %%
numerical_cols = data.select_dtypes(include=np.number).columns

for col in numerical_cols:
    Q1 = data[col].quantile(0.25)
    Q3 = data[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    data = data[(data[col] >= lower_bound) & (data[col] <= upper_bound)]

# %%
data.describe()
# Out:
#                 X1          age       gender       height       weight  \
# count  6264.000000  6264.000000  6264.000000  6264.000000  6264.000000
# mean   1771.144317    29.158525     0.476533   169.709052    69.614464
# std    1097.988748     8.908978     0.499489    10.324698    13.451878
# min       1.000000    18.000000     0.000000   143.000000    43.000000
# 25%     789.750000    23.000000     0.000000   160.000000    60.000000
# 50%    1720.000000    28.000000     0.000000   168.000000    68.000000
# 75%    2759.250000    33.000000     1.000000   180.000000    77.300000
# max    3670.000000    56.000000     1.000000   191.000000   115.000000
#
#              steps    hear_rate     calories     distance  entropy_heart  \
# count  6264.000000  6264.000000  6264.000000  6264.000000    6264.000000
# mean    109.562268    86.142331    19.471823    13.832555       6.030314
# std     222.797908    28.648385    27.309765    45.941437       0.765574
# ...

# %% [markdown]
# # 7. Encode columns wherever required with appropriate Encoding Techniques.

# %%
from sklearn.preprocessing import LabelEncoder

# %%
enc = LabelEncoder()
data['activity'] = enc.fit_transform(data['activity'])
data['gender'] = enc.fit_transform(data['gender'])

# %%
data['device'] = enc.fit_transform(data['device'])

# %%
data.head()
# Out:
#    X1  age  gender  height  weight      steps  hear_rate   calories  distance  \
# 0   1   20       1   168.0    65.4  10.771429  78.531302   0.344533  0.008327
# 1   2   20       1   168.0    65.4  11.475325  78.453390   3.287625  0.008896
# 2   3   20       1   168.0    65.4  12.179221  78.540825   9.484000  0.009466
# 3   4   20       1   168.0    65.4  12.883117  78.628260  10.154556  0.010035
# 4   5   20       1   168.0    65.4  13.587013  78.715695  10.825111  0.010605
#
#    entropy_heart  entropy_setps  resting_heart  corr_heart_steps  norm_heart  \
# 0       6.221612       6.116349           59.0          1.000000   19.531302
# 1       6.221612       6.116349           59.0          1.000000   19.453390
# 2       6.221612       6.116349           59.0          1.000000   19.540825
# 3       6.221612       6.116349           59.0          1.000000   19.628260
# 4       6.221612       6.116349           59.0          0.982816   19.715695
#
# ...

# %% [markdown]
# # 8. Scale data wherever required with appropriate Scaling Techniques.

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc = StandardScaler()
numerical_cols = ['age', 'height', 'weight', 'steps', 'hear_rate', 'calories', 'distance']
data[numerical_cols] = sc.fit_transform(data[numerical_cols])

# %% [markdown]
# # 9. Bifurcate the data as per predictors and target

# %%
x = data.drop(columns=['activity'])
y = data['activity']

# %% [markdown]
# # 10. Bifurcate the data for training and testing the model

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x, y, test_size=0.8, random_state=50)

# %% [markdown]
# # 11. Train the data with appropriate model.

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
list = [8,9,10,11,12,20,30,40,50]
for i in list:
    model = RandomForestClassifier(random_state=i)
    model.fit(x_train, y_train)
    print(model.score(x_test, y_test))
# Out:
# 0.7390263367916999
# 0.7440143655227454
# 0.7446129289704708
# 0.7422186751795691
# 0.7392258579409418
# 0.734437350359138
# 0.7402234636871509
# 0.7386272944932163
# 0.7426177174780527

# %%
model = RandomForestClassifier(random_state=10) #so we have checked random_state size 10 gives more score we use 10 here

# %%
model.fit(x_train, y_train)
# Out:
# RandomForestClassifier(random_state=10)

# %% [markdown]
# # 12. Find out the accuracy which serves the best

# %%
model.score(x_test, y_test)
# Out:
# 0.7446129289704708

# %% [markdown]
# # 13. Create a confusion matrix for the results achieved

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# %%
x_predicted = model.predict(x_test)
cmt = confusion_matrix(y_test, pre_data)
matrix = ConfusionMatrixDisplay(confusion_matrix=cmt)
matrix.plot()

# %% [markdown]
# # 14. Find out the Precision and Recall score.

# %%
from sklearn.metrics import precision_score, recall_score

# %%
list = ['micro', 'macro', 'weighted']
for i in list:
    print(precision_score(y_test, x_predicted, average=i))
    print(recall_score(y_test, x_predicted, average=i))
# Out:
# 0.7446129289704708
# 0.7446129289704708
# 0.7466443628722979
# 0.7414597035780721
# 0.7444069180128063
# 0.7446129289704708

# %%
precision_score(y_test, x_predicted, average='macro') #we have checked macro is giving more score so we use macro
# Out:
# 0.7466443628722979

# %%
recall_score(y_test, x_predicted, average='macro')
# Out:
# 0.7414597035780721

# %% [markdown]
# # 15. Based on the F1 score, is the model reliable?

# %%
from sklearn.metrics import f1_score,classification_report

# %%
list = ['micro', 'macro', 'weighted']
for i in list:
    print(f1_score(y_test, x_predicted, average=i))
# Out:
# 0.7446129289704708
# 0.7428849506978591
# 0.7433379335888167

# %%
f1_score(y_test, x_predicted, average='micro') #we have checked micro is giving more score so we use micro
# Out:
# 0.7446129289704708

# %%
#if f1 > 0.75 then model is reliable

# %%
print(classification_report(y_test,x_predicted))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.69      0.75      0.72      1094
#            1       0.76      0.74      0.75       763
#            2       0.76      0.72      0.74       811
#            3       0.81      0.85      0.83       888
#            4       0.76      0.78      0.77       702
#            5       0.71      0.60      0.65       754
#
#     accuracy                           0.74      5012
#    macro avg       0.75      0.74      0.74      5012
# weighted avg       0.74      0.74      0.74      5012
